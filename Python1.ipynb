# %% [markdown]
# <a href="https://colab.research.google.com/github/rkmorya789/AI-class/blob/main/Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(" hello world")
print("neha")
# Out:
#  hello world
# neha

# %%
# my biodata
print("****  BIODATA  ****")
print("name        :  neha")
print("age         :  21")
print("dob.        :  23-08-2005")
print("father name :  Rakesh kumar ")
print("mother name :  Rekha Rani ")
print("height      :  5.1")
print("gmail       :  rkmorya789@gmail.com")
print("status      :  graduation complete in 2026")
print("language    :  hindi, punjabi, english")
print("belong to   :  bathinda city")
# Out:
# ****  BIODATA  ****
# name        :  neha
# age         :  21
# dob.        :  23-08-2005
# father name :  Rakesh kumar
# mother name :  Rekha Rani
# height      :  5.1
# gmail       :  rkmorya789@gmail.com
# status      :  graduation complete in 2026
# language    :  hindi, punjabi, english
# belong to   :  bathinda city

# %%
print("coke:40")
print("pizza:300")
print("burger:80")
print("momos:50")
print("total bill:470")
# Out:
# coke:40
# pizza:300
# burger:80
# momos:50
# total bill:470

# %%
# HOME GROCERY
print("***BATH ITEMS ***")
print("bathtub        :  400")
print("kitchen cleaner:  100")
print("soup wipes     :  50")
print("washing powder :  100")
print("harpic         :  100")
print("facewash       :  100")
print("mug            :  50")
print("***TOTAL       :  900***")

print("**KITCHEN UNSTEAL**")

print("wok.           :  400")
print("pan.           :  200")
print("bowl.          :  200")
print("6 plates.      :  600")
print("6 spoon.       :  100")
print("roller pin.    :  150")
print("pitcher.       :  100")
print("6 glass.       :  400")
print("Piler          :  50")
print("whiskers       :  100")
print("mortar         :  200")
print("***TOTAL       :  2600***")

print("**ELECTRIC ITEMS **")

print("juicer.        :  5000")
print("iron.          :  3000")
print("washing machine:  15000")
print("AC.            :  45000")
print("refrigerator.  :  17000")
print("***TOTAL       :  85000***")
print("+++GRAND TOTAL :  88500+++")
# Out:
# ***BATH ITEMS ***
# bathtub        :  400
# kitchen cleaner:  100
# soup wipes     :  50
# washing powder :  100
# harpic         :  100
# facewash       :  100
# mug            :  50
# ***TOTAL       :  900***
# **KITCHEN UNSTEAL**
# wok.           :  400
# pan.           :  200
# bowl.          :  200
# 6 plates.      :  600
# 6 spoon.       :  100
# roller pin.    :  150
# pitcher.       :  100
# 6 glass.       :  400
# Piler          :  50
# whiskers       :  100
# mortar         :  200
# ***TOTAL       :  2600***
# **ELECTRIC ITEMS **
# juicer.        :  5000
# iron.          :  3000
# washing machine:  15000
# AC.            :  45000
# refrigerator.  :  17000
# ***TOTAL       :  85000***
# +++GRAND TOTAL :  88500+++

# %%
first_number=4
second_number=5
total_result=first_number+second_number
average=total_result/2
print("addition of two number",total_result)
print("average of both number",average)
# Out:
# addition of two number 9
# average of both number 4.5

# %%
chips=50
choclate=20
fruity=30
print("**CITY MALL**")
print("price of chips.   :",chips)
print("price of choclate :",choclate)
print("price of fruity   :",fruity)
total_bill=chips+choclate+fruity
print("total bill of all things ",total_bill)
discount=total_bill * 10/100
pay_bill=total_bill-discount
print("after discount:",pay_bill)
print("discount apply:", discount)
# Out:
# **CITY MALL**
# price of chips.   : 50
# price of choclate : 20
# price of fruity   : 30
# total bill of all things  100
# after discount: 90.0
# discount apply: 10.0

# %%
addition=20
subtraction= 30
print(addition+subtraction)
print(addition-subtraction)
print(addition*subtraction)
print(addition/subtraction)
print(addition%subtraction)
# Out:
# 50
# -10
# 600
# 0.6666666666666666
# 20

# %%
bowl=100
Discount=bowl*20/100
Pay_bill=bowl-discount
print(pay_bill)
# Out:
# 90.0

# %%
print("[***BILL RECEIPT***]")
bowl=400
total_bill=bowl
discount=total_bill*25/100
pay_bill=total_bill-discount
print(pay_bill)
# Out:
# [***BILL RECEIPT***]
# 300.0

# %%
almira=2000
total_bill=almira
discount=total_bill*20/100
pay_amount=total_bill-discount
print("after discount",pay_amount)
print("almira rate ", almira)
print("apply discount", discount)
double_bed=70000
bill=double_bed
rebait=bill*20/100
amount=bill-rebait
print("double bed",double_bed)
print("apply discount",rebait)
print("after discount",amount)
# Out:
# after discount 1600.0
# almira rate  2000
# apply discount 400.0
# double bed 70000
# apply discount 14000.0
# after discount 56000.0

# %%
laptop_price=50000
discount=laptop_price*25/100
now_pay=laptop_price-discount
print("laptop price", laptop_price)
print("apply discount", discount)
print("now pay",now_pay)
table_rate=1500
discount_apply=table_rate*25/100
total_pay=table_rate-discount_apply
print("table rate",table_rate)
print("apply discount", discount_apply)
print("now your total balance is ",total_pay)
chair_rate=2000
discount_on_chair=chair_rate*25/100
your_total_bill=chair_rate-discount_on_chair
print("chair price ",chair_rate)
print(" discount rate",discount_on_chair)
print("your total payment ",your_total_bill)
# Out:
# laptop price 50000
# apply discount 12500.0
# now pay 37500.0
# table rate 1500
# apply discount 375.0
# now your total balance is  1125.0
# chair price  2000
#  discount rate 500.0
# your total payment  1500.0

# %%
payment=2500
rate=5
time_limit=7
simple_interest=payment*rate*time_limit/100
total_payment=simple_interest+payment
print(total_payment)
# Out:
# 3375.0

# %%
principal=int(input("enter the amount"))
rate=3
time=1
si=principal*rate*time/100
total_payment=si+principal
print(total_payment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1729/644143251.py in <cell line: 0>()
# ----> 1 principal=int(input("enter the amount"))
#       2 rate=3
#       3 time=1
#       4 si=principal*rate*time/100
#       5 total_payment=si+principal
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
principal=30000
rate=5
time=2
si=principal*rate*time/100
total_payment=si+principal
print(total_payment)

# %%
principal=60000
rate=5
time=15
si=principal*rate*time/100
total=si+principal
print(total)

# %%
principal=7000
rate=5
time=34
si=principal*rate*time/100
total=si+principal
print(total)

# %%
p=5000
r=5
t=2
t_in_day=10
t_in_month=t_in_day/30
si=p*r*t/100
si_interest=p*r*t_in_month/100
total=p+si+si_interest
print(total)

# %%
p=3000
r=2
t=7
t_in_day=9
t_in_month=t_in_day/30
si=p*r*t/100
interest=p*r*t_in_month/100
total=p+si+interest
print(total)

# %%
p=100000
r=9
t=2
t_in_day=27
t_in_month=t_in_day/30
si=p*r*t/100
interest=p*r*t_in_month/100
total=p+si+interest
print(total)

# %%
p=9000
r=3
r=13
si=p*r*t/100
total=p+si
print(total)

# %%
P=5000
R=9
T=23
P=2300
R=2.5
T=9

# %%
p=5000
r=9
t=27
t_in_day=27/30
si=p*r*t_in_day/100
total=si+p
print(total)
print(si)

# %%
p=23000
r=2.5
t=9
si=p*r*t/100
total=si+p
print(total)

# %%
chips=int(input("enter rate chips"))
chocolate=int(input("enter rate choclate"))
toffee=int(input("enter rate coffe"))
add_rate=chips+chocolate+toffee
discount=add_rate*20/100
pay_now=add_rate-discount
print("total item rate  ",add_rate)
print("20% less discount", discount)
print("pay now          ",pay_now)

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
C=a+b
print(C)

# %%
print("**MY BIODATA***")
name=input("enter name")
age=input("enter age")
grade=input("your grade")
father_name=input("enter father name")
mother_name=input("enter mother name")
contact=int(input("enter number"))
email=input("enter mail Id")
gender=input("enter your gender")
married_status=bool(input("enter status"))
city=input("your city")
address=input("your address fill")
print("my name is.              ",name)
print("my age is                ",age)
print("my grade is.             ",grade)
print("my father name is.       ",father_name)
print("my mother name isb.      ",mother_name)
print("my contact number is this",contact)
print("my email I'd is this     ",email)
print("I am                    ",gender)
print("I am not married.        ", married_status)
print("I am belong to           ",city)
print("my address is.           ",address)

# %%
print("***MORYA MOMOS BILL***")

chips=int(input("enter chips rate"))
coffee=int(input("enter coffee rate"))
pizza=int(input(" enter pizza rate"))
burger=int(input("enter burger rate"))
fries=int(input("enter fries rate "))
momos=int(input("enter momos rate"))
chilli_chaap=int(input("enter chilli chaap rate "))
colddrink=int(input("enter colddrink rate"))
total=chips+coffee+pizza+burger+fries+momos+chilli_chaap+colddrink
discount=total*10/100
total_bill=total-discount
print("**YOUR BILL PLS PAY NOW**")
print("price on chips        ",chips)
print("price on coffee       ",coffee)
print("price on pizza        ",pizza)
print("price on burger       ",burger)
print("price on fries        ",fries)
print("price on momos        ",momos)
print("price on chillichaap  ",chilli_chaap)
print("price on colddrink    ",colddrink)
print("after discount        ",discount)
print("total payment now     ",total_bill)

# %%
n=int(input("enter the number"))
if n%9==0:
  print("yes its dvide by 9")
else:
  print("no its not divide by 9")

# %%
a=int(input("enter the value"))
b=int(input("enter the value"))
sum=a+b
if sum<100:
  print("yes is lessthen 100")
else:
  print("no is morethen 100")

# %%
principal=int(input("enter the principal"))
rate=int(input("enter the rate"))
time=int(input("enter the time limit"))
simple_interest=principal*rate*time/100
si=simple_interest+principal
print("this is interest amount",simple_interest)
print("its your total amlount",si)

# %%
principal=int(input("enter the total payment"))
rate=int(input("enter the monthly interest"))
time=int(input("enter the time limit"))
simple_interest=principal*rate*time/100
si=simple_interest+principal
print("your total amount is this",si)

# %%
a=int(input("enter the number"))
if a%4==0:
  print("yes this even number")
else:
  print("no this odd number")

# %%
gender=input("pls enter gender")
if gender=="female";
  print("entry allow")
else:
  print("not allow")

# %%
cheak_number=int(input("enter number"))
if cheak_number>0:
  print(" yes its positive number")
elif cheak_number==0:
  print("this number is non negitive number")
else :
  print("this number is negitive number")

# %%
number=int(input("enter number"))
if number%3==0:
  print("yes this divide by 3")
elif number%5==0:
  print("yes this divide by 5")
elif number%7==0:
  print("yes this divide by 7")
else:
  print("no its not divide")

# %%
number=int(input("enter the number by divisible"))
if number%1000==0:
  print("yes this number divisible by 1000")
elif number%100==0:
  print("yes this number divisible by 100")
elif number%10==0:
  print("yes this divisble by 10")
else:
  print("no this number not divisble ")

# %%
number=int(input("enter the value divisible by "))
if number%2==0:
  print("yes its divisible by 2 ")
elif number%5==0:
  print("yes its divisible by 5")
elif number%10==0:
  print("yes its divisble by 10")
else:
  print("its not divisible number")

# %%
week=input("enter the weekday name")

if week=="saturday" or week=="sunday" :
  print("its weekend day")
else:
  print("its not weekend day")

# %%
vote=int(input("enter your age"))
if vote>=18:
  print("eligble for  voting")
else:
  print("note eligble voting")

# %%
# BIODATA
name=input("enter your name")
father=input("enter your father name")
mother=input("enter your mother name")
age=int(input("enter your age"))
email=input("enter email id")
address=("enter your address")
city=input("enter your city")
print("my name is        :",name)
print("my father name is :",father)
print("my mother name is :",mother)
print("my age            :",age)
print("my email id is    :",email)
print("my adddress       :",address)
print("my city is        :",city)

# %%
number1=5
number2=10
total=number1+number2
average=total/2
print(total)
print(average)

# %%
chips=int(input("enter the chips rate"))
choclate=int(input("enter the choclate rate"))
total=chips+choclate
discount=total*5/100
now_pay=total-discount
print("your bill     :",now_pay)
print("discount apply:",discount)

# %%
chips=input("enter chips")
if chips=="lays" or chips=="bingo" or chips=="kurkure" or chips=="too yum" or chips=="tagz":
  print("rate=20")
else:
  print("its not under 20")

# %%
# **KABIRA CAFE**
print("***KABIRA CAFE***")
cold_Coffee=120
cappuccino=110
masala_Tea=60
veg_Sandwich=130
cheese_Sandwich=160
crench_Fries=120
peri_Fries=150
veg_Burger=160
print("cold_coffee      :",cold_Coffee)
print("cappuccino       :",cappuccino)
print("masala_Tea       :",masala_Tea)
print("veg_Sandwich     :",veg_Sandwich)
print("cheese_Sandwich  :",cheese_Sandwich)
print("crench_Fries     :",crench_Fries)
print("peri_Fries       :",peri_Fries)
print("veg_Burger       :",veg_Burger)

# %%
# **DIWALI OFFER**
print("**DIWALI OFFER**")
bed=int(input("enter bed price"))
table=int(input("enter table price"))
chair=int(input("enter chair price"))
sofa=int(input("enter sofa price"))
desk=int(input("enter desk price"))
total=bed+table+chair+sofa+desk
discount=total*15/100
pay_bill=total-discount
print("total amount   :",total)
print("apply discount :",discount)
print("your total bill:",pay_bill)

# %%
principal=int(input("enter the principal"))
rate=int(input("enter the rate"))
time=int(input("enter the time limit"))
si=principal*rate*2
time/100
total=si+principal
print("your interest           :",si)
print("now your total amount   :",total)

# %%
p=int(input("enter principal            "))
r=int(input("enter rate                 "))
t=int(input("enter time limit in months "))
time_in_days=int(input("enter the days  "))
time_in_month=time_in_days/30
si=p*r*t/100
interest=p*r*time_in_month/100
total=si+p+interest
print("your monthly interest is this            :",si)
print("your daily interset is this              :", interest)
print(" your total amount included all interest :",total)

# %%
number=int(input("enter the number"))
if number%5==0 and number%7!=0:
  print("its dvisible by 5 but not divisble by 7")
else:
  print("condition false")

# %%
age=int(input("enter the age"))
if age>=18:
        print("eligible for vote ")
else:
        print("your not eligible for vote")

# %%
p=int(input("enter your principal"))
r=int(input("enter your rate"))
time=int(input("enter your time"))
days=int(input("enter day"))
month=input("enter month")
if month=="January" or month=="march" or month=="may" or month=="July" or month=="august" or month=="October" or month=="December":
 days_in_month=31
elif month=="April" or month=="June" or month=="September" or month=="November":
 days_in_month=30
else:
  year=int(input("enter the year"))
  if year%4==0 and year%100!=0 or year%400==0:
    days_in_month=29
  else:
    days_in_month=28
    days_in_converted=days/days_in_month
    si=p*r*time/100
    simple_interest=p*r*days_in_converted/100
    total=si+simple_interest
    total_payment=total+p
    print(total)
    print(total_payment)
# Out:
# enter your principal4500
# enter your rate2
# enter your time2
# enter day0
# enter monthjune
# enter the year2500
# 180.0
# 4680.0

# %%
num=int(input("enter your num"))
remainder=num % 6
edit_num=num+remainder
print(edit_num)
print(remainder)
# Out:
# enter your num52
# 56
# 4

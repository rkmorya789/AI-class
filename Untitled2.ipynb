# %% [markdown]
# <a href="https://colab.research.google.com/github/rkmorya789/AI-class/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("enter the age"))
if age>=21:
  print("yes her age is adult")
else:
  print("no his childe")
# Out:
# enter the age25
# yes her age is adult

# %%
number1=int(input("enter the value"))
if number1>=80:
  print("GRADE A")
elif number1<=50:
  print("GRADE B")
elif number1<=33:
  print("GRADE C")
else:
  print("FAIL")
# Out:
# GRADE A

# %%
marks=int(input("enter marks"))
attend=int(input("enter attend"))
if marks>=70 and attend>=75:
  print("yes its able to addmission becouse its marks and attendense is full fhill for addmision")
else:
  print("its not able to addmissin becouse its note fullfill attendense and marks for according to policy")
# Out:
# enter marks78
# enter attend65
# yes its able to addmission becouse its marks and attendense is full fhill for addmision

# %%
password=input("enter the paasword ")
username=input("enter id")
if password=="neha123" and username=="nehamorya786":
  print("login succsessfully")
else:
  print("not match")
# Out:
# enter the paasword gug
# enter idutbu
# not match

# %%
number=int(input("enter number"))
if number<=50 and number>=10:
  print("ture")
else:
  print("false")
# Out:
# enter number98
# false

# %%
p=int(input("enter number"))
r=int(input("enter the rate interest"))
t=int(input("enter the time limit"))
si=p*r*t/100
total=si+p
print(total)
# Out:
# enter number4500
# enter the rate interest6
# enter the time limit8
# 6660.0

# %%
number=int(input("enter the name"))
if number>=10 or number<=100:
  print("yes its true condition")
else :
  print("false condition")
# Out:
# enter the name-4
# yes its true condition
